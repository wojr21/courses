# %% [markdown]
# <a href="https://colab.research.google.com/github/wojr21/courses/blob/main/data_visualization/01_seaborn_relplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
sns.set()

# %%
df = sns.load_dataset('fmri')
df.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(data = df, x = 'timepoint', y = 'signal', kind = 'line')

# %%
sns.relplot(data = df, x = 'timepoint', y = 'signal', kind = 'line', ci = None)

# %%
df.describe().T
# Out:
#             count     mean       std  ...       50%        75%        max
# timepoint  1064.0  9.00000  5.479801  ...  9.000000  14.000000  18.000000
# signal     1064.0  0.00354  0.093930  ... -0.013653   0.024293   0.564985
#
# [2 rows x 8 columns]

# %%
df['timepoint'].value_counts()
# Out:
# 18    56
# 8     56
# 1     56
# 2     56
# 3     56
# 4     56
# 5     56
# 6     56
# 7     56
# 9     56
# 17    56
# 10    56
# 11    56
# 12    56
# 13    56
# 14    56
# 15    56
# 16    56
# 0     56
# Name: timepoint, dtype: int64

# %%
df.groupby('timepoint').agg('mean')
# Out:
#              signal
# timepoint
# 0         -0.016662
# 1         -0.025002
# 2         -0.012873
# 3          0.034446
# 4          0.098194
# 5          0.137725
# 6          0.127515
# 7          0.075660
# 8          0.013420
# 9         -0.032041
# 10        -0.053685
# 11        -0.058194
# 12        -0.052526
# 13        -0.043532
# 14        -0.033660
# 15        -0.025880
# 16        -0.022414
# 17        -0.021368
# 18        -0.021867

# %%
df.groupby('timepoint').agg('mean').plot()

# %%
sns.relplot(data = df, x = 'timepoint', y = 'signal', hue = 'event',
            kind = 'line', style = 'event', markers = True, col = 'region')

# %%
df['subject'].value_counts()
# Out:
# s12    76
# s11    76
# s4     76
# s1     76
# s13    76
# s5     76
# s6     76
# s10    76
# s0     76
# s8     76
# s3     76
# s7     76
# s9     76
# s2     76
# Name: subject, dtype: int64

# %%
sns.relplot(data = df, x = 'timepoint', y = 'signal', hue = 'event',
            kind = 'line', style = 'event', markers = True, col = 'subject',
            col_wrap = 4)
