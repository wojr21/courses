# %% [markdown]
# <a href="https://colab.research.google.com/github/wojr21/courses/blob/main/data_visualization/27_plotly_casestudy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q chart_studio
# !pip install -q --upgrade plotly
# Out:
#      |████████████████████████████████| 71kB 2.1MB/s
#      |████████████████████████████████| 13.2MB 297kB/s

# %%
def fetch_financial_data(company = 'AMZN'):
  import pandas_datareader.data as web
  return web.DataReader(name = company, data_source = 'stooq')

# %%
df_amzn = fetch_financial_data(company = 'AMZN')
df_aapl = fetch_financial_data(company = 'AAPL')
df_msft = fetch_financial_data(company = 'MSFT')
df_nflx = fetch_financial_data(company = 'NFLX')
df_twtr = fetch_financial_data(company = 'TWTR')

# %%
df_amzn.head()
# Out:
#                  Open       High      Low    Close   Volume
# Date
# 2020-12-24  3193.9000  3202.0000  3169.00  3172.69  1451917
# 2020-12-23  3205.0000  3210.1300  3184.17  3185.27  2093787
# 2020-12-22  3202.8434  3222.0000  3180.08  3206.52  2381781
# 2020-12-21  3200.0100  3226.9666  3166.00  3206.18  3836846
# 2020-12-18  3243.9900  3249.4200  3171.60  3201.65  5995713

# %%
import pandas as pd

# %%
df = pd.concat([df_amzn['Close'], df_aapl['Close'], df_msft['Close'],
                df_nflx['Close'], df_twtr['Close']],
               axis = 1, join = 'inner')
df.columns = ['amazon', 'apple', 'microsoft', 'netflix', 'twitter']
df = df.reset_index()
df.head()
# Out:
#         Date   amazon    apple  microsoft  netflix  twitter
# 0 2020-12-24  3172.69  131.970     222.75   513.97    53.97
# 1 2020-12-23  3185.27  130.960     221.02   514.48    54.30
# 2 2020-12-22  3206.52  131.880     223.94   527.33    54.91
# 3 2020-12-21  3206.18  128.230     222.59   528.91    54.64
# 4 2020-12-18  3201.65  126.655     218.59   534.45    55.87

# %%
df.describe().T
# Out:
#             count         mean         std  ...       50%       75%      max
# amazon     1257.0  1550.289010  740.705084  ...  1601.860  1883.160  3531.45
# apple      1257.0    50.284128   26.089094  ...    42.636    55.454   133.95
# microsoft  1257.0   107.143250   51.315540  ...    97.818   136.600   231.05
# netflix    1257.0   271.600111  129.788907  ...   291.450   362.200   556.55
# twitter    1257.0    28.122745    9.894117  ...    29.420    35.020    55.87
#
# [5 rows x 8 columns]

# %%
import plotly.graph_objects as go

# %%
trace0 = go.Scatter(x = df['Date'],
                    y = df['amazon'],
                    name = 'Amazon')
trace1 = go.Scatter(x = df['Date'],
                    y = df['apple'],
                    name = 'Apple')
trace2 = go.Scatter(x = df['Date'],
                    y = df['microsoft'],
                    name = 'Microsoft')
trace3 = go.Scatter(x = df['Date'],
                    y = df['netflix'],
                    name = 'Netflix')
trace4 = go.Scatter(x = df['Date'],
                    y = df['twitter'],
                    name = 'Twitter')
data = [trace0, trace1, trace2, trace3, trace4]

layout = go.Layout(yaxis_type = 'log')

fig = go.Figure(data = data, layout = layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = go.Figure()

fig.add_trace(go.Scatter(
    x = df['Date'],
    y = df['amazon'],
    name = 'Amazon'
))

fig.add_trace(go.Scatter(
    x = df['Date'],
    y = df['apple'],
    name = 'Apple'
))

fig.add_trace(go.Scatter(
    x = df['Date'],
    y = df['microsoft'],
    name = 'Microsoft'
))

fig.add_trace(go.Scatter(
    x = df['Date'],
    y = df['netflix'],
    name = 'Netflix'
))

fig.add_trace(go.Scatter(
    x = df['Date'],
    y = df['twitter'],
    name = 'Twitter'
))

fig.update_layout(
    yaxis_type = 'log'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data = [go.Scatter(x = df['Date'], y = df[col], name = col) for col in df.columns[1:]]
layout = go.Layout(yaxis_type = 'log')

fig = go.Figure(data = data, layout = layout)
fig.write_html('price.html')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
