# %% [markdown]
# <a href="https://colab.research.google.com/github/wojr21/courses/blob/main/data_visualization/03_seaborn_jointplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
sns.set()

# %%
sns.set(style = 'darkgrid')

df = np.random.multivariate_normal(mean = [0, 1], cov = [(1, -0.4), (-0.4, 1)],
                                   size = 200)
df = pd.DataFrame(df, columns = ['x', 'y'])
df.head()
# Out:
#           x         y
# 0  0.050458  0.587930
# 1  1.766849  1.376458
# 2  1.670158 -1.426641
# 3  0.111014  2.963808
# 4 -0.964434  2.207519

# %%
df.describe().T
# Out:
#    count      mean       std       min       25%       50%       75%       max
# x  200.0  0.059897  0.991441 -2.891538 -0.634585  0.144054  0.811957  2.339529
# y  200.0  0.974005  0.926102 -1.427268  0.336528  1.047442  1.603815  3.594307

# %%
sns.jointplot(data = df, x = 'x', y = 'y')

# %%
sns.set(style = 'white')
sns.jointplot(data = df, x = 'x', y = 'y', kind = 'hex')

# %%
sns.jointplot(data = df, x = 'x', y = 'y', kind = 'kde')

# %%
g = sns.jointplot(data = df, x = 'x', y = 'y', kind = 'kde', n_levels = 15,
                  cmap = 'viridis')
g.plot_joint(plt.scatter, s = 30, marker = '+')
